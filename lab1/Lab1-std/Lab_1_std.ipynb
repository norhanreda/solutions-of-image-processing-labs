# %%
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray,rgb2hsv
import matplotlib.pyplot as plt
import numpy as np
from skimage.util import random_noise
import numpy as np

from skimage.exposure import histogram
from matplotlib.pyplot import bar

# %%
def show_images(images,titles=None):
    #This function is used to show image(s) with titles by sending an array of images and an array of associated titles.
    # images[0] will be drawn with the title titles[0] if exists
    # You aren't required to understand this function, use it as-is.
    n_ims = len(images)
    if titles is None: titles = ['(%d)' % i for i in range(1,n_ims + 1)]
    fig = plt.figure()
    n = 1
    for image,title in zip(images,titles):
        a = fig.add_subplot(1,n_ims,n)
        if image.ndim == 2: 
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
        n += 1
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_ims)
    plt.show()

# %%
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray,rgb2hsv
import matplotlib.pyplot as plt
import numpy as np
from skimage.util import random_noise
import numpy as np

from skimage.exposure import histogram
from matplotlib.pyplot import bar


# Ex: imread and imshow 
pyramids = io.imread('pyramids.jpeg')
io.imshow(pyramids)
io.show()

# %%
# Use this function to show a histogram
# The image should be gray-scale and should range from 0 to 1
def showHist(img,histogramImg):
    plt.figure()
    bar(histogramImg[1]*255, histogramImg[0], width=0.8, align='center')

# %%
'''
@TODO:
Requirement #1 
-Read and print image 'coffee'  
-Show and print half of the  image
-----hint :use the attribute shape of numpy to get the image object dimentions
'''
#imports
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline

import numpy as np

#-Read and print image 'coffee' 
# read coffee 
coffee = io.imread('coffee.jpeg')
#print coffe
print(coffee)
# show coffee
io.imshow(coffee)
io.show()

#-Show and print half of the  image

# 3D ( row, column, channel)

print(coffee.shape)
halfcoffe=np.copy(coffee)
height, width,channel = halfcoffe.shape
width_cutoff = width // 2
height_cutoff = height // 2
s1 = halfcoffe[:, :width_cutoff]
s2=halfcoffe[:height_cutoff, :]
io.imshow(s1)
io.show()

io.imshow(s2)
io.show()
# Out:
# [[[222 223 241]
#   [222 223 241]
#   [222 223 241]
#   ...
#   [204 205 226]
#   [204 205 226]
#   [204 205 226]]
#
#  [[222 223 241]
#   [222 223 241]
#   [222 223 241]
#   ...
#   [204 205 226]
#   [204 205 226]
#   [204 205 226]]
#
#  [[222 223 241]
#   [222 223 241]
#   [222 223 241]
#   ...
#   [204 205 226]
#   [204 205 226]
#   [204 205 226]]
#
#  ...
#
#  [[229 231 244]
#   [229 231 244]
#   [229 231 244]
#   ...
#   [228 230 243]
#   [228 230 243]
#   [228 230 243]]
#
#  [[229 231 244]
#   [229 231 244]
#   [229 231 244]
#   ...
#   [228 230 243]
#   [228 230 243]
#   [228 230 243]]
#
#  [[229 231 244]
#   [229 231 244]
#   [229 231 244]
#   ...
#   [228 230 243]
#   [228 230 243]
#   [228 230 243]]]
# (446, 640, 3)

# %%
'''
@TODO:
Requirement #2 
RGB to gray and HSV:
1- Write a function 'gray_image' that takes an image as input , then
    -get the gray scale of the image, then
    -display original image and the gray scale one side by side (subplot).
    -hint: use rgb2gray to get the graylevel of the image
- test your function with the image 'pyramids'
    
2- Write a function 'HSV_image' that takes an image as input , then
   -show the RGB image and the (3 channels of HSV image each channel in separated form ) one side by side (subplot).
   -hint: -use rgb2hsv (to get the hsv representation of the image).
          -To separately get the Hue, Saturation and Value channels, use hsvImg[:,:,X], 
           where hsvImg is the hsv representation of the image. 
           Hue is the first channel, Saturation is the second and value is the last channel.
- test your function for the images in HSV Folder. And comment on the results. 
'''
#1- grey color
#imports
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray,rgb2hsv
import matplotlib.pyplot as plt
import numpy as np

# function gray_image
def gray_image(image):
    copy_image=np.copy(image)
    gray_img= rgb2gray(copy_image)
    fig, axs = plt.subplots(1,2)
    fig.suptitle('gray scale')
    axs[0].imshow(image)
    axs[1].imshow(gray_img,cmap='gray')


pyramids=io.imread('pyramids.jpeg')
gray_image(image=pyramids)

# io.imshow(grey_pyramids)
# io.show()

# io.imshow(pyramids)
# io.show()



# ax1 = plt.subplot(2,2,1)
# io.imshow(pyramids)
# ax2 = plt.subplot(2,2,2)
# io.imshow(grey_pyramids)

# ax3=plt.subplot(2,2,3)
# io.imshow(pyramids)
# ax4=plt.subplot(2,2,4)
# io.imshow(pyramids)




# fig = plt.figure()
# fig.add_subplot(2, 2, 1)
# plt.imshow(pyramids)
# plt.title("First")
# fig.add_subplot(2, 2, 2)
# plt.imshow(grey_pyramids,cmap='gray')
# plt.title("First")
# fig.add_subplot(2, 2, 3)
# plt.imshow(pyramids)
# plt.title("First")
# fig.add_subplot(2, 2, 4)
# plt.imshow(grey_pyramids)
# plt.title("First")


#2-hsv color

def HSV_image(image):
    copy_image=np.copy(image)
    hsv_img= rgb2hsv(copy_image)
    hue_img = hsv_img[:, :, 0]
    sat_img = hsv_img[:, :, 1]
    value_img = hsv_img[:, :, 2]
    fig,( (ax0, ax1), (ax2, ax3)) = plt.subplots(2,2)
    fig.suptitle('hsv')
    ax0.imshow(image)
    ax0.set_title('original')
    ax0.axis('off')
    ax1.imshow(hue_img,cmap='hsv')
    ax1.set_title('hue')
    ax1.axis('off')
    ax2.imshow(sat_img,cmap='gray')
    ax2.set_title('saturation')
    ax2.axis('off')
    ax3.imshow(value_img,cmap='gray')
    ax3.set_title('value')
    ax3.axis('off')


#HSV_image(image=pyramids)

hsv_ex1=io.imread('hsv\ex1.png')
hsv_ex2=io.imread('hsv\ex2.jpg')
hsv_ex3=io.imread('hsv\ex3.jpg')

HSV_image(image=hsv_ex1)
HSV_image(image=hsv_ex2)
HSV_image(image=hsv_ex3)
# hsv_img= rgb2hsv(pyramids)
# hue_img = hsv_img[:, :, 0]
# io.imshow(hue_img,cmap='hsv')
# io.show()
# HSV_pyramids=HSV_image(image=pyramids)
# io.imshow(HSV_pyramids)
# io.show()

# io.imshow(pyramids)
# io.show()

# %%
'''
Requirement 2 (Noise):
http://scikit-image.org/docs/dev/api/skimage.util.html#skimage.util.random_noise

1.For an image of your choice (the effect of noise must be obvious): 
    Read the image.
    Convert it to greyscale.
    Apply salt & pepper noise with 
    amount=0.05, 0.5 and 0.9
   
2. From the other images. Recommend one image that won’t be greatly affected by the noise and state why.    
    '''


# imports
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
from skimage.util import random_noise
import numpy as np


# read coffee 
pyramids = io.imread('pyramids.jpeg')
#print coffe
print(pyramids)
# show coffee
io.imshow(pyramids)
io.show()

# geay scale  
def gray_image(image):
    copy_image=np.copy(image)
    return rgb2gray(copy_image)
     
    


gray_img=gray_image(pyramids) 
io.imshow(gray_img)
io.show()

#amount=0.05
noise_img1=random_noise(gray_img,mode='s&p',amount=0.05)
io.imshow(noise_img1)
io.show()

#amount=0.5
noise_img2=random_noise(gray_img,mode='s&p',amount=0.5)
io.imshow(noise_img2)
io.show()

#amount=0.9
noise_img3=random_noise(gray_img,mode='s&p',amount=0.9)
io.imshow(noise_img3)
io.show()
# Out:
# [[[  0   0  92]
#   [  0   0  92]
#   [  0   0  93]
#   ...
#   [  0   0 106]
#   [  0   1 104]
#   [  0   1 104]]
#
#  [[  0   0  92]
#   [  0   0  92]
#   [  0   0  93]
#   ...
#   [  0   1 107]
#   [  0   1 104]
#   [  0   1 104]]
#
#  [[  0   0  92]
#   [  0   0  92]
#   [  0   0  93]
#   ...
#   [  0   1 107]
#   [  0   2 105]
#   [  0   1 104]]
#
#  ...
#
#  [[125  82  29]
#   [138  99  40]
#   [152 117  53]
#   ...
#   [132  93  36]
#   [125  84  30]
#   [125  82  31]]
#
#  [[138  96  38]
#   [150 110  48]
#   [160 125  57]
#   ...
#   [137  98  41]
#   [131  90  36]
#   [132  89  38]]
#
#  [[141  96  37]
#   [156 117  52]
#   [162 125  57]
#   ...
#   [147 106  50]
#   [137  94  41]
#   [136  90  40]]]

# %%
'''
Requirement 3 (Histogram):

1- For the given images ( in histogram folder): 
    Read the image.
    Apply histogram and show it.
Hint
    A) Use histogram (image) to get histogram. Try different values for nbins (256,64,8), What does it mean?
    B) and function(showHist) to draw it.
** 2- Draw a grey-scale image that has uniform histogram 
same number of pixels for all intensity levels) using code only. Let the size of the image be 256x256.
use np.ones to draw image with ones.
'''

#imports
import skimage.io as io

# Show the figures / plots inside the notebook
# %matplotlib inline
from skimage.color import rgb2gray,rgb2hsv
import matplotlib.pyplot as plt
import numpy as np
from skimage.util import random_noise
import numpy as np

from skimage.exposure import histogram 
from matplotlib.pyplot import bar


#fuctions

# A)

def histogram (image):
 copy_image=np.copy(image)   
 hist=np.histogram(copy_image, bins=10)
 return hist
 
 

# B)

def showHist(histogram_array):
    print(histogram_array)
    plt.figure()
    plt.hist(histogram_array, bins='auto')

 

hist_ex1=io.imread('histogram\ex1.jpg')
hist_ex2=io.imread('histogram\ex2.png')
hist_ex3=io.imread('histogram\ex3.png')

hist1=histogram (hist_ex1)
showHist(hist1)
hist2=histogram (hist_ex2)
showHist(hist2)
hist3=histogram (hist_ex3)
showHist(hist3)
# Out:
# (array([    195,   44094, 1146405, 5069115, 8088165, 8414007, 6705957,
#        4718244, 5335008,  978810], dtype=int64), array([ 70. ,  88.5, 107. , 125.5, 144. , 162.5, 181. , 199.5, 218. ,
#        236.5, 255. ]))
# (array([ 587205,  560634,  562197,  560520,  560634,  562197,  560520,
#         560634,  562197, 3217662], dtype=int64), array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#        229.5, 255. ]))
# (array([159702, 274680, 174219, 102111,  70563,  52401,  40947,  32364,
#         25815,  17598], dtype=int64), array([  0. ,  22.9,  45.8,  68.7,  91.6, 114.5, 137.4, 160.3, 183.2,
#        206.1, 229. ]))
